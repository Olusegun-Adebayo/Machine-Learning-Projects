# %%
import sklearn
import pandas as pd

# %% [markdown]
# The dataset we will be working with is the Breast Cancer
# Wisconsin Diagnostic Database. The dataset includes various information
# about breast cancer tumors, as well as classification labels of malignant or
# benign. The dataset has 569 instances, or data, on 569 tumors and
# includes information on 30 attributes, or features, such as the radius of
# the tumor, texture, smoothness, and area.
#
# Using this dataset, we will build a machine learning model to use
# tumor information to predict whether or not a tumor is malignant or benign.

# %%
from sklearn.datasets import load_breast_cancer

# %%
data = load_breast_cancer()

# %% [markdown]
# The data variable is a
# dictionary. The important dictionary keys to consider are the
# classification label names (target_names), the actual labels (target),
# the attribute/feature names (feature_names), and the attributes
# (data).

# %%
# extracting te required keys and data

label_names = data['target_names']
labels = data['target']
feature_names = data['feature_names']
features = data['data']

# %%
# We split our data into training and testing sets randomly

from sklearn.model_selection import train_test_split

# %%
Br_Cancer_df_full = pd.DataFrame(features, columns = feature_names)

# %%
features[0][1]
# Out:
# 10.38

# %%
Br_Cancer_df_full.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
# use 20% of the data for testing

train, test, train_labels, test_labels = train_test_split(features, labels, test_size=0.2, random_state = 20)

# %%
# displaying our taining data as a data frame
Br_Cancer_df = pd.DataFrame(train, columns = feature_names)
Br_Cancer_df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        9.397         21.68           59.75      268.8          0.07969
# 1       27.420         26.27          186.90     2501.0          0.10840
# 2       13.680         16.33           87.76      575.5          0.09277
# 3       14.870         20.21           96.12      680.9          0.09587
# 4       15.850         23.95          103.70      782.7          0.08401
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.06053         0.03735             0.005128         0.1274
# 1           0.19880         0.36350             0.168900         0.2061
# 2           0.07255         0.01752             0.018800         0.1631
# 3           0.08345         0.06824             0.049510         0.1487
# 4           0.10020         0.09938             0.053640         0.1847
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.06724  ...         9.965          27.99            66.61
# 1                 0.05623  ...        36.040          31.37           251.20
# 2                 0.06155  ...        15.850          20.20           101.60
# 3                 0.05748  ...        16.010          28.48           103.90
# 4                 0.05338  ...        16.840          27.66           112.00
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0       301.0            0.1086             0.1887           0.1868
# 1      4254.0            0.1357             0.4256           0.6833
# 2       773.4            0.1264             0.1564           0.1206
# 3       783.6            0.1216             0.1388           0.1700
# 4       876.5            0.1131             0.1924           0.2322
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0               0.02564          0.2376                  0.09206
# 1               0.26250          0.2641                  0.07427
# 2               0.08704          0.2806                  0.07782
# 3               0.10170          0.2369                  0.06599
# 4               0.11190          0.2809                  0.06287
#
# [5 rows x 30 columns]

# %%
# Checking the size of the train an testing sets

print("Shape of the training set:{}".format(train.shape))
print("Shape of the testing set:{}".format(test.shape))
# Out:
# Shape of the training set:(455, 30)
# Shape of the testing set:(114, 30)

# %%
# Building the model
# importing the knn and NaiveBayes Classifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier

# %%
# Initializing the classifiers

knn = KNeighborsClassifier()
gnb = GaussianNB()

# %%
# Training the classifiers

model_knn = knn.fit(train, train_labels)
model_gnb = gnb.fit(train, train_labels)

# %%
# Predict
pred_gnb = gnb.predict(test)
pred_knn = knn.predict(test)

# %%
# Evaluate accuracy of the models
print("The knn model is {:.0f}% accurate".format(100*knn.score(test, test_labels)))
print("The Naive Bayes model is {:.0f}% accurate".format(100*gnb.score(test, test_labels)))
# Out:
# The knn model is 94% accurate
# The Naive Bayes model is 96% accurate

# %%
# Checking the correlation

Br_Cancer_df.corr()
# Out:
#                          mean radius  mean texture  mean perimeter  mean area  \
# mean radius                 1.000000      0.335562        0.997825   0.986915
# mean texture                0.335562      1.000000        0.342777   0.334494
# mean perimeter              0.997825      0.342777        1.000000   0.986124
# mean area                   0.986915      0.334494        0.986124   1.000000
# mean smoothness             0.186999      0.011513        0.222977   0.195324
# mean compactness            0.538553      0.277757        0.588484   0.529235
# mean concavity              0.682190      0.326041        0.721228   0.692146
# mean concave points         0.828758      0.321453        0.856845   0.829458
# mean symmetry               0.170871      0.075981        0.206332   0.173631
# mean fractal dimension     -0.285813     -0.027356       -0.234645  -0.256038
# radius error                0.684842      0.282427        0.697951   0.739775
# texture error              -0.074243      0.373783       -0.060752  -0.041096
# perimeter error             0.681920      0.288708        0.701782   0.734743
# area error                  0.728338      0.270026        0.738377   0.795639
# smoothness error           -0.191214      0.018440       -0.171834  -0.134763
# compactness error           0.239011      0.226583        0.282777   0.244027
# concavity error             0.197648      0.149494        0.230793   0.212393
# concave points error        0.393464      0.180316        0.424016   0.387102
# symmetry error             -0.076655      0.016236       -0.053364  -0.038505
# fractal dimension error     0.000741      0.101463        0.038093   0.024816
# worst radius                0.968073      0.373951        0.968310   0.959367
# worst texture               0.294429      0.914819        0.303321   0.285993
# worst perimeter             0.963354      0.379543        0.969214   0.955176
# worst area                  0.940624      0.370442        0.941746   0.957597
# worst smoothness            0.120439      0.111979        0.151121   0.124065
# worst compactness           0.413290      0.307283        0.454593   0.388004
# worst concavity             0.515769      0.320569        0.552609   0.501401
# worst concave points        0.740911      0.316833        0.767914   0.716324
# worst symmetry              0.165959      0.116711        0.191504   0.145000
# worst fractal dimension     0.022445      0.166057        0.065204   0.019250
#
#                          mean smoothness  mean compactness  mean concavity  \
# mean radius                     0.186999          0.538553        0.682190
# mean texture                    0.011513          0.277757        0.326041
# mean perimeter                  0.222977          0.588484        0.721228
# mean area                       0.195324          0.529235        0.692146
# mean smoothness                 1.000000          0.641251        0.514858
# mean compactness                0.641251          1.000000        0.893336
# mean concavity                  0.514858          0.893336        1.000000
# mean concave points             0.554310          0.844777        0.918336
# mean symmetry                   0.564916          0.605563        0.511946
# mean fractal dimension          0.563446          0.550447        0.365618
# radius error                    0.323937          0.517916        0.642010
# texture error                   0.126681          0.092885        0.110494
# perimeter error                 0.316899          0.576963        0.673053
# area error                      0.267493          0.477419        0.623114
# smoothness error                0.347768          0.120107        0.111648
# compactness error               0.309283          0.740915        0.692777
# concavity error                 0.240943          0.567529        0.697365
# concave points error            0.381438          0.651087        0.695372
# symmetry error                  0.219729          0.218325        0.192084
# fractal dimension error         0.276093          0.516286        0.511787
# worst radius                    0.228875          0.570473        0.695639
# worst texture                   0.078924          0.301602        0.323206
# worst perimeter                 0.255813          0.628298        0.738212
# worst area                      0.225781          0.546232        0.687577
# worst smoothness                0.802334          0.552542        0.439851
# worst compactness               0.451136          0.860262        0.747691
# worst concavity                 0.420694          0.825079        0.879734
# worst concave points            0.502455          0.835149        0.859523
# worst symmetry                  0.394315          0.507706        0.410607
# worst fractal dimension         0.448947          0.663282        0.519210
#
#                          mean concave points  mean symmetry  \
# mean radius                         0.828758       0.170871
# mean texture                        0.321453       0.075981
# mean perimeter                      0.856845       0.206332
# mean area                           0.829458       0.173631
# mean smoothness                     0.554310       0.564916
# mean compactness                    0.844777       0.605563
# mean concavity                      0.918336       0.511946
# mean concave points                 1.000000       0.484140
# mean symmetry                       0.484140       1.000000
# mean fractal dimension              0.182388       0.481269
# radius error                        0.705877       0.317869
# texture error                       0.061538       0.137727
# perimeter error                     0.722077       0.328856
# area error                          0.690603       0.241593
# smoothness error                    0.039712       0.175456
# compactness error                   0.508044       0.420073
# concavity error                     0.434730       0.343471
# concave points error                0.625821       0.404599
# symmetry error                      0.112383       0.439222
# fractal dimension error             0.295857       0.345748
# worst radius                        0.837297       0.212465
# worst texture                       0.318146       0.112520
# worst perimeter                     0.864250       0.247636
# worst area                          0.819283       0.204938
# worst smoothness                    0.444909       0.438750
# worst compactness                   0.658253       0.470226
# worst concavity                     0.738878       0.441813
# worst concave points                0.908402       0.459118
# worst symmetry                      0.382004       0.713224
# worst fractal dimension             0.363022       0.422129
#
#                          mean fractal dimension  ...  worst radius  \
# mean radius                           -0.285813  ...      0.968073
# mean texture                          -0.027356  ...      0.373951
# mean perimeter                        -0.234645  ...      0.968310
# mean area                             -0.256038  ...      0.959367
# mean smoothness                        0.563446  ...      0.228875
# mean compactness                       0.550447  ...      0.570473
# mean concavity                         0.365618  ...      0.695639
# mean concave points                    0.182388  ...      0.837297
# mean symmetry                          0.481269  ...      0.212465
# mean fractal dimension                 1.000000  ...     -0.224854
# radius error                           0.014072  ...      0.719980
# texture error                          0.230383  ...     -0.090218
# perimeter error                        0.064014  ...      0.702841
# area error                            -0.062605  ...      0.746677
# smoothness error                       0.358509  ...     -0.207582
# compactness error                      0.548502  ...      0.239472
# concavity error                        0.475874  ...      0.191769
# concave points error                   0.348654  ...      0.375714
# symmetry error                         0.325647  ...     -0.103479
# fractal dimension error                0.689104  ...      0.007693
# worst radius                          -0.224854  ...      1.000000
# worst texture                          0.024722  ...      0.366325
# worst perimeter                       -0.170814  ...      0.993272
# worst area                            -0.199405  ...      0.983859
# worst smoothness                       0.496443  ...      0.219124
# worst compactness                      0.469138  ...      0.480809
# worst concavity                        0.388584  ...      0.565528
# worst concave points                   0.206740  ...      0.786067
# worst symmetry                         0.344899  ...      0.251658
# worst fractal dimension                0.756023  ...      0.113327
#
#                          worst texture  worst perimeter  worst area  \
# mean radius                   0.294429         0.963354    0.940624
# mean texture                  0.914819         0.379543    0.370442
# mean perimeter                0.303321         0.969214    0.941746
# mean area                     0.285993         0.955176    0.957597
# mean smoothness               0.078924         0.255813    0.225781
# mean compactness              0.301602         0.628298    0.546232
# mean concavity                0.323206         0.738212    0.687577
# mean concave points           0.318146         0.864250    0.819283
# mean symmetry                 0.112520         0.247636    0.204938
# mean fractal dimension        0.024722        -0.170814   -0.199405
# radius error                  0.199606         0.725181    0.760272
# texture error                 0.398598        -0.078504   -0.058571
# perimeter error               0.204761         0.728043    0.739452
# area error                    0.198426         0.751074    0.804861
# smoothness error             -0.057116        -0.194376   -0.159106
# compactness error             0.194588         0.298337    0.235643
# concavity error               0.110883         0.231459    0.196812
# concave points error          0.109256         0.413366    0.360239
# symmetry error               -0.056152        -0.076230   -0.077413
# fractal dimension error       0.063366         0.048870    0.024252
# worst radius                  0.366325         0.993272    0.983859
# worst texture                 1.000000         0.372595    0.356427
# worst perimeter               0.372595         1.000000    0.977007
# worst area                    0.356427         0.977007    1.000000
# worst smoothness              0.271595         0.239147    0.212301
# worst compactness             0.406229         0.535858    0.444132
# worst concavity               0.389848         0.610389    0.538142
# worst concave points          0.380931         0.815959    0.746062
# worst symmetry                0.263588         0.279325    0.220233
# worst fractal dimension       0.285941         0.160271    0.102093
#
#                          worst smoothness  worst compactness  worst concavity  \
# mean radius                      0.120439           0.413290         0.515769
# mean texture                     0.111979           0.307283         0.320569
# mean perimeter                   0.151121           0.454593         0.552609
# mean area                        0.124065           0.388004         0.501401
# mean smoothness                  0.802334           0.451136         0.420694
# mean compactness                 0.552542           0.860262         0.825079
# mean concavity                   0.439851           0.747691         0.879734
# mean concave points              0.444909           0.658253         0.738878
# mean symmetry                    0.438750           0.470226         0.441813
# mean fractal dimension           0.496443           0.469138         0.388584
# radius error                     0.146395           0.287362         0.377551
# texture error                   -0.027000          -0.056990        -0.044097
# perimeter error                  0.130926           0.345873         0.416780
# area error                       0.124135           0.281422         0.376605
# smoothness error                 0.299317          -0.072093        -0.057531
# compactness error                0.226903           0.694655         0.673499
# concavity error                  0.162940           0.483037         0.671635
# concave points error             0.212919           0.454229         0.558929
# symmetry error                  -0.018536           0.035534         0.037711
# fractal dimension error          0.179928           0.427226         0.454837
# worst radius                     0.219124           0.480809         0.565528
# worst texture                    0.271595           0.406229         0.389848
# worst perimeter                  0.239147           0.535858         0.610389
# worst area                       0.212301           0.444132         0.538142
# worst smoothness                 1.000000           0.558866         0.508279
# worst compactness                0.558866           1.000000         0.895875
# worst concavity                  0.508279           0.895875         1.000000
# worst concave points             0.541822           0.802143         0.847717
# worst symmetry                   0.490704           0.607678         0.533799
# worst fractal dimension          0.592349           0.816855         0.711041
#
#                          worst concave points  worst symmetry  \
# mean radius                          0.740911        0.165959
# mean texture                         0.316833        0.116711
# mean perimeter                       0.767914        0.191504
# mean area                            0.716324        0.145000
# mean smoothness                      0.502455        0.394315
# mean compactness                     0.835149        0.507706
# mean concavity                       0.859523        0.410607
# mean concave points                  0.908402        0.382004
# mean symmetry                        0.459118        0.713224
# mean fractal dimension               0.206740        0.344899
# radius error                         0.530226        0.099968
# texture error                       -0.089988       -0.108189
# perimeter error                      0.555093        0.117274
# area error                           0.526628        0.078610
# smoothness error                    -0.102369       -0.121496
# compactness error                    0.509754        0.282769
# concavity error                      0.440691        0.202498
# concave points error                 0.613655        0.152940
# symmetry error                      -0.029862        0.355360
# fractal dimension error              0.268674        0.133728
# worst radius                         0.786067        0.251658
# worst texture                        0.380931        0.263588
# worst perimeter                      0.815959        0.279325
# worst area                           0.746062        0.220233
# worst smoothness                     0.541822        0.490704
# worst compactness                    0.802143        0.607678
# worst concavity                      0.847717        0.533799
# worst concave points                 1.000000        0.512463
# worst symmetry                       0.512463        1.000000
# worst fractal dimension              0.523442        0.526962
#
#                          worst fractal dimension
# mean radius                             0.022445
# mean texture                            0.166057
# mean perimeter                          0.065204
# mean area                               0.019250
# mean smoothness                         0.448947
# mean compactness                        0.663282
# mean concavity                          0.519210
# mean concave points                     0.363022
# mean symmetry                           0.422129
# mean fractal dimension                  0.756023
# radius error                            0.052576
# texture error                          -0.007803
# perimeter error                         0.093813
# area error                              0.026261
# smoothness error                        0.052663
# compactness error                       0.593762
# concavity error                         0.451792
# concave points error                    0.309128
# symmetry error                          0.029632
# fractal dimension error                 0.617678
# worst radius                            0.113327
# worst texture                           0.285941
# worst perimeter                         0.160271
# worst area                              0.102093
# worst smoothness                        0.592349
# worst compactness                       0.816855
# worst concavity                         0.711041
# worst concave points                    0.523442
# worst symmetry                          0.526962
# worst fractal dimension                 1.000000
#
# [30 rows x 30 columns]

# %%
 # feature engineering

# %%
# columns to remove from features

col_del = ['worst radius', 'worst perimeter', 'worst area', 'mean perimeter']

# %%
# get their index locations

col_del_index  = [Br_Cancer_df.columns.get_loc(c) for c in col_del]

# %%
import numpy as np

# %%
features_new = np.delete(features,col_del_index, axis=1)

# %%
features_new.shape
# Out:
# (569, 26)

# %%
# use 20% of the data for testing


train_1, test_1, train_labels, test_labels = train_test_split(features_new, labels, test_size=0.2, random_state = 20)

# %%
# Checking the size of the train an testing sets

print("Shape of the training set:{}".format(train_1.shape))
print("Shape of the testing set:{}".format(test_1.shape))
# Out:
# Shape of the training set:(455, 26)
# Shape of the testing set:(114, 26)

# %%
model_knn = knn.fit(train_1, train_labels)
model_gnb = gnb.fit(train_1, train_labels)

# %%
pred_gnb_1 = gnb.predict(test_1)
pred_knn_1= knn.predict(test_1)

# %%
# Evaluate accuracy of the models
print("The knn model is {:.0f}% accurate".format(100*knn.score(test_1, test_labels)))
print("The Naive Bayes model is {:.0f}% accurate".format(100*gnb.score(test_1, test_labels)))
# Out:
# The knn model is 95% accurate
# The Naive Bayes model is 90% accurate

# %%
# reducing multilple correlated features reduced the accuracy of Naive Bayes but increased that of Knn
